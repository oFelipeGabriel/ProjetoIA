# %%
from sklearn import datasets

iris = datasets.load_iris()
print(iris.feature_names)
print(iris.target_names)
print(len(iris.data))
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']
# 150

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

X, y = iris.data, iris.target


mlp = MLPClassifier(solver='adam', alpha=0.0001, hidden_layer_sizes=(5,), random_state=1, learning_rate='constant',
                   learning_rate_init=0.01, max_iter=500, activation='logistic', momentum=0.9, verbose=True, 
                   tol=0.0001)



X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.3, random_state=1)
mlp.fit(X_treino, y_treino)
saidas = mlp.predict(X_teste)

print('-----------------------------------------------------')


print("Saida da rede: \t", saidas)
print("Saida desejada: ", y_teste)

print("Score: ", (saidas==y_teste).sum()/len(X_teste))
print("Score: ", mlp.score(X_teste, y_teste))
# Out:
# Iteration 1, loss = 1.18795672
# Iteration 2, loss = 1.17021522
# Iteration 3, loss = 1.15363403
# Iteration 4, loss = 1.13829910
# Iteration 5, loss = 1.12428364
# Iteration 6, loss = 1.11164396
# Iteration 7, loss = 1.10039467
# Iteration 8, loss = 1.09047283
# Iteration 9, loss = 1.08171414
# Iteration 10, loss = 1.07387242
# Iteration 11, loss = 1.06667804
# Iteration 12, loss = 1.05988899
# Iteration 13, loss = 1.05331480
# Iteration 14, loss = 1.04682002
# Iteration 15, loss = 1.04031678
# Iteration 16, loss = 1.03375414
# Iteration 17, loss = 1.02710779
# Iteration 18, loss = 1.02037102
# Iteration 19, loss = 1.01354723
# Iteration 20, loss = 1.00664388
# Iteration 21, loss = 0.99966771
# Iteration 22, loss = 0.99262129
# Iteration 23, loss = 0.98550097
# Iteration 24, loss = 0.97829650
# Iteration 25, loss = 0.97099204
# Iteration 26, loss = 0.96356846
# Iteration 27, loss = 0.95600640
# Iteration 28, loss = 0.94828930
# Iteration 29, loss = 0.94040578
# ...

# %%
import pandas as pd
names = ['Area de Desmatamento', 'Area', 'Co2 1ª Ordem','Co2 2ª Ordem', 'Co2 2ª Ordem - Queimadas', 'Co2 2ª Ordem - Desmatamento']
co2 = pd.read_table('co2 (cópia).csv',sep=',')
#co2 = co2.T
x = co2.iloc[0:39,1:7]
y = co2.iloc[39:78,1]
print(x.shape)
print(y.shape)
x.head()
# Out:
# (39, 6)
# (39,)
#    Area de Desmatamento  D_AreaAcc  Co2 1ª Ordem  Co2 2ª Ordem  \
# 0                842754   842754.0         459.0         149.0
# 1                842754  1685508.0         459.0         247.0
# 2                842754  2528262.0         459.0         309.0
# 3                842754  3371016.0         459.0         347.0
# 4                842754  4213770.0         459.0         373.0
#
#    Co2 2ª Ordem - Queimadas  Co2 2ª Ordem - Desmatamento
# 0                     149.0                          0.0
# 1                     149.0                         98.0
# 2                     149.0                        159.0
# 3                     149.0                        198.0
# 4                     149.0                        224.0

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.75, random_state=15)

# %%
mlp = MLPClassifier(solver='adam', alpha=0.000001, hidden_layer_sizes=(8,8,8), random_state=75, learning_rate='constant',
                   learning_rate_init=0.0001, max_iter=25600, activation='logistic', momentum=0.25, verbose=True, 
                   tol=0.000001)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_treino)

X_train = scaler.transform(X_treino)
X_test = scaler.transform(X_teste)

mlp.fit(X_treino,y_treino)

saidas = mlp.predict(X_teste)
# Out:
# Iteration 1, loss = 2.09949431
# Iteration 2, loss = 2.09929733
# Iteration 3, loss = 2.09910078
# Iteration 4, loss = 2.09890468
# Iteration 5, loss = 2.09870903
# Iteration 6, loss = 2.09851385
# Iteration 7, loss = 2.09831912
# Iteration 8, loss = 2.09812488
# Iteration 9, loss = 2.09793111
# Iteration 10, loss = 2.09773782
# Iteration 11, loss = 2.09754503
# Iteration 12, loss = 2.09735274
# Iteration 13, loss = 2.09716095
# Iteration 14, loss = 2.09696967
# Iteration 15, loss = 2.09677890
# Iteration 16, loss = 2.09658865
# Iteration 17, loss = 2.09639893
# Iteration 18, loss = 2.09620973
# Iteration 19, loss = 2.09602107
# Iteration 20, loss = 2.09583294
# Iteration 21, loss = 2.09564535
# Iteration 22, loss = 2.09545831
# Iteration 23, loss = 2.09527181
# Iteration 24, loss = 2.09508586
# Iteration 25, loss = 2.09490047
# Iteration 26, loss = 2.09471563
# Iteration 27, loss = 2.09453135
# Iteration 28, loss = 2.09434762
# Iteration 29, loss = 2.09416446
# ...

# %%
from IPython.display import display, Markdown
display(Markdown('## Saida da rede:'))
print(saidas)
display(Markdown("## Saida desejada: "))
print(y_teste)

print("Score: ", (saidas==y_teste).sum()/len(X_teste))
print("Score: ", mlp.score(X_teste, y_teste))
# Out:
# ## Saida da rede:
# [ 789300  789300  789300  789300  789300  789300  789300  789300  789300
#   789300 1725900 1725900  789300  789300  789300  789300  789300  789300
#   789300  789300  789300  789300  789300  789300  789300  789300  789300
#   789300  789300  789300]
# ## Saida desejada:
# 69     694713
# 68     789300
# 59     694713
# 58     789300
# 42    2165088
# 53     589095
# 70     789300
# 57     694713
# 63     694713
# 64     789300
# 40    1822600
# 41    1816500
# 77     694713
# 45    1901393
# 55     620687
# 72     789300
# 65     694713
# 76     789300
# 75     694713
# 71     694713
# 48    1291096
# 43    2539514
# 73     694713
# 49     746365
# 74     789300
# 62     789300
# 52     457100
# 56     789300
# 54     501199
# 61     694713
# Name: Area de Desmatamento, dtype: int64
# Score:  0.3
# Score:  0.3
